# %%
import pandas as pd

# %%
df = pd.read_csv('매물_대구_아파트.csv')

# %%
df.head()
# Out:
#   거래종류 매물종류         매물명 공급면적 전용면적      매매가    보증금  융자금  연세     월세  ...  난방연료  \
# 0   매매  아파트       부영6단지  79㎡  60㎡  17000.0      0    0 NaN    NaN  ...  도시가스
# 1   매매  아파트       부영6단지  79㎡  60㎡  17200.0      0    0 NaN    NaN  ...  도시가스
# 2   매매  아파트     아람주공9단지  79㎡  59㎡  15700.0      0    0 NaN    NaN  ...   열병합
# 3   월세  아파트     아람주공9단지  79㎡  59㎡      NaN   1000    0 NaN  600.0  ...   열병합
# 4   전세  아파트  시지대백신화창신맨션  82㎡  60㎡      NaN  15000    0 NaN    NaN  ...  도시가스
#
#    계단형태  건축년도  지하철정보   입주가능  테마정보  매물설명                지번주소  \
# 0   복합식  2002    NaN  1개월이내   NaN   NaN  대구광역시 북구 구암동 789-1
# 1   복합식  2002    NaN  1개월이내   NaN   NaN  대구광역시 북구 구암동 789-1
# 2   복합식  1997    NaN  2개월이내   NaN   NaN  대구광역시 달서구 도원동 1440
# 3   복합식  1997    NaN  1개월이내   NaN   NaN  대구광역시 달서구 도원동 1440
# 4   복도식  1994    NaN  1개월이내   NaN   NaN   대구광역시 수성구 신매동 569
#
#                     도로명주소                       건설사명
# 0  대구광역시 북구 구암동 구암로49길 24                동광주택산업 주식회사
# ...
